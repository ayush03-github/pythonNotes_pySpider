# %%
for i in range(5):
    print(i)
    i += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print("start")
# Out:
# start

# %%
n = int(input("n: "))
for i in range(n):
    for j in range(n-1-i):
        print(" ",end="")
    for k in range(i+1):
        print("*",end=" " )
    print()
